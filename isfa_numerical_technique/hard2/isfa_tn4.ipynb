# %%
import pandas as pd

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df=pd.read_html("https://www.ined.fr/fr/tout-savoir-population/chiffres/france/mortalite-cause-deces/taux-mortalite-sexe-age/")[0]
df
# Out:
#           Unnamed: 0  Total  Hommes  Femmes
# 0          Tous âges     99     102      97
# 1   moins d’1 an (a)     35      38      31
# 2          1 à 4 ans      3       3       3
# 3          5 à 9 ans      1       1       1
# 4        10 à 14 ans      1       1       1
# 5        15 à 19 ans      2       3       1
# 6        20 à 24 ans      4       6       2
# 7        25 à 29 ans      5       7       3
# 8        30 à 34 ans      6       9       4
# 9        35 à 39 ans      9      12       5
# 10       40 à 44 ans     13      18       8
# 11       45 à 49 ans     20      26      14
# 12       50 à 54 ans     32      42      22
# 13       55 à 59 ans     49      66      33
# 14       60 à 64 ans     75     103      50
# 15       65 à 69 ans    112     155      75
# 16       70 à 79 ans    198     266     141
# 17       80 à 89 ans    606     760     505
# 18      90 à 110 ans   2002    2336    1875

# %%
df.columns = df.iloc[0]
df=df.iloc[1:]

# %%
df.to_csv("../data/sujet4/taux_de_mort.csv",index=False)
